# %%
import numpy as np
import pandas as pd
import sklearn.feature_extraction.text as extraction
from langdetect import detect
import time
from google.cloud import translate_v2 as translate
import nltk
import nltk.stem as stem
from nltk import word_tokenize as tokenize
import re
import string
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]='/Users/hamilton/Desktop/Stuff/GoogleAPIKey/MovieTranslation-f8371579c36e.json'

# %% [markdown]
# Preprocessing:
# - removing all data whos feature vector is irregular (longer than the column of 44 or something)
# - removed all commas in CSV so that it doesn't interfere with the read_csv
# - drop features with missing values
# - deleted non-movies
# - threw out data with multiple parentheses appearences
# - translate all titles to english
# - removed year and other parentheses from title
# - choosing to use snowball(Porter2) stemmer
# - remove punctuation
#
# Steps:
# - remove the year in title
# - remove other punctuation
# - translate to english
# - stem the title
#
# TO DO:
# - Parse our own title
#
# Visualization:
# - distribution of languages for movies (maybe keep track of performance for certain language of movie titles)

# %% [markdown]
# # Loading  Data

# %%
def load_data():
    client = translate.Client()
    stemmer = stem.snowball.EnglishStemmer()    
    table = str.maketrans('','',string.punctuation)
    data = pd.read_csv("./imdbmovies/imdb.csv", nrows=200)
    
    idxRemove = data[np.logical_not(np.isnan(data['Unnamed: 44']))].index
    dataCleaned = data.drop(idxRemove)
    idxNonMovie = dataCleaned[dataCleaned["type"] != 'video.movie'].index
    dataCleaned.drop(idxNonMovie, inplace=True)
    idxTwoParen = dataCleaned[dataCleaned["title"].str.contains("\(.*\(")].index
    dataCleaned.drop(idxTwoParen, inplace=True)

    dataCleaned.drop(columns=["Unnamed: 44", "Unnamed: 45", "Unnamed: 46", "Unnamed: 47"], inplace=True)
    dataCleaned.dropna(axis=0, inplace=True)
    dataCleaned.reset_index(inplace=True)
    dataCleaned.drop(columns=["index", "url", "tid", "fn", "wordsInTitle", "type"], inplace=True)
    dataCleaned.title = dataCleaned.title.apply(lambda title: re.sub(r'\(([ a-zA-Z]*)([0-9]{4})\)', r'\1', title))\
                                    .apply(lambda title: title.translate(table))\
                                    .apply(lambda title: client.translate(title)["translatedText"])\
                                    .apply(lambda title: " ".join([stemmer.stem(word) for word in tokenize(title)]))
    
    X = dataCleaned.iloc[:, :11]
    y = dataCleaned.iloc[:, 11:]
    
    return X, y

# %%
start = time.time()
X, y = load_data()
print("Time to load data: {} seconds".format(time.time() - start))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-53ff0ca0fd3f> in <module>
#       1 start = time.time()
# ----> 2 X, y = load_data()
#       3 print("Time to load data: {} seconds".format(time.time() - start))
#
# <ipython-input-1-ef158b170071> in load_data()
#      18                                     .apply(lambda title: title.translate(table))\
#      19                                     .apply(lambda title: client.translate(title)["translatedText"])\
# ---> 20                                     .apply(lambda title: " ".join([stemmer.stem(word) for word in tokenize(title)]))
#      21
#      22     X = dataCleaned.iloc[:, :11]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-1-ef158b170071> in <lambda>(title)
#      18                                     .apply(lambda title: title.translate(table))\
#      19                                     .apply(lambda title: client.translate(title)["translatedText"])\
# ---> 20                                     .apply(lambda title: " ".join([stemmer.stem(word) for word in tokenize(title)]))
#      21
#      22     X = dataCleaned.iloc[:, :11]
#
# <ipython-input-1-ef158b170071> in <listcomp>(.0)
#      18                                     .apply(lambda title: title.translate(table))\
#      19                                     .apply(lambda title: client.translate(title)["translatedText"])\
# ---> 20                                     .apply(lambda title: " ".join([stemmer.stem(word) for word in tokenize(title)]))
#      21
#      22     X = dataCleaned.iloc[:, :11]
#
# NameError: name 'stemmer' is not defined

# %%
print("Labels ", y.columns.to_list())
print("Features ", X.columns.to_list())
# Out:
# Labels  ['Action', 'Adult', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'FilmNoir', 'GameShow', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News', 'RealityTV', 'Romance', 'SciFi', 'Short', 'Sport', 'TalkShow', 'Thriller', 'War', 'Western']
# Features  ['title', 'imdbRating', 'ratingCount', 'duration', 'year', 'nrOfWins', 'nrOfNominations', 'nrOfPhotos', 'nrOfNewsArticles', 'nrOfUserReviews', 'nrOfGenre']

# %%
# X.to_csv("./imdbmovies/features.csv", index=False)
# y.to_csv("./imdbmovies/labels.csv", index=False)

# %%
X
# Out:
#                           title imdbRating ratingCount  duration  year  \
# 0    the vagabond and the child        8.4       40550    3240.0  1921
# 1                     gold rush        8.3       45319    5700.0  1925
# 2                     metropoli        8.4       81007    9180.0  1927
# 3                   the general        8.3       37521    6420.0  1926
# 4                    citi light        8.7       70057    5220.0  1931
# ..                          ...        ...         ...       ...   ...
# 192                 the downfal        8.3      184234    9360.0  2004
# 193                      oldboy        8.4      245394    7200.0  2003
# 194                batman begin        8.3      659591    8400.0  2005
# 195                befor sunset        8.1      113580    4800.0  2004
# 196                rwanda hotel        8.2      195628    7260.0  2004
#
#     nrOfWins nrOfNominations  nrOfPhotos  nrOfNewsArticles  nrOfUserReviews  \
# 0          1               0          19                96               85
# 1          2               1          35               110              122
# 2          3               4          67               428              376
# 3          1               1          53               123              219
# 4          2               0          38               187              186
# ..       ...             ...         ...               ...              ...
# 192       18              17          16               432              532
# 193       18              11          19               121              742
# 194        9              44         202              6136             2607
# 195        8              12          34               719              467
# 196       14              34          27               461              582
#
#      nrOfGenre
# 0            3
# 1            3
# 2            2
# 3            3
# 4            3
# ..         ...
# 192          3
# 193          3
# 194          3
# 195          2
# 196          3
#
# [197 rows x 11 columns]

# %% [markdown]
# # Text Vectorization

# %%
tfidfVector = extraction.TfidfVectorizer()
hashVector = extraction.HashingVectorizer()

# %%
text = ["The quick brown fox jumped over the lazy dog.",
        "The dog.",
        "The fox"]
titles = X.title.tolist()

# %%
transOrig = tfidfVector.fit_transform(X.title)

# %%
transOrig.shape
# Out:
# (197, 385)

# %%
transEng = tfidfVectorEng.fit_transform(titlesEng)

# %%
print(tfidfVectorEng.transform(['The']))
# Out:
#   (0, 7665)	1.0

# %%
tfidfVectorEng.get_stop_words()

# %%
tfidfVectorEng.get_feature_names()
# Out:
# ['00',
#  '000',
#  '007',
#  '01',
#  '10',
#  '100',
#  '1000',
#  '1001',
#  '101',
#  '102',
#  '105',
#  '109',
#  '10th',
#  '11',
#  '1138',
#  '117',
#  '12',
#  '120',
#  '127',
#  '13',
#  '13th',
#  '14',
#  '1408',
#  '1453',
#  '1492',
#  '15',
#  '16',
#  '17',
#  '174',
#  '1776',
#  '18',
#  '180',
#  '1812',
#  '18th',
#  '19',
#  '1901',
#  '1911',
#  '1931',
#  '1935',
#  '1937',
#  '1938',
#  '1939',
#  '1941',
#  '1942',
#  '1944',
#  '1950',
#  '1953',
#  '1962',
#  '1974',
#  '1980',
#  '1983',
#  '1987',
#  '1989',
#  '1991',
#  '1998',
#  '1999',
#  '19th',
#  '1st',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2002',
#  '2004',
#  '2006',
#  '2009',
#  '2011',
#  '2012',
#  '2019',
#  '2022',
#  '2046',
#  '2077',
#  '20th',
#  '21',
#  '211',
#  '21st',
#  '22',
#  '23',
#  '237',
#  '23rd',
#  '24',
#  '25',
#  '25th',
#  '27',
#  '27th',
#  '28',
#  '2nd',
#  '30',
#  '300',
#  '3000',
#  '33',
#  '35',
#  '36',
#  '39',
#  '3d',
#  '3rd',
#  '40',
#  '420',
#  '42nd',
#  '43',
#  '45',
#  '451',
#  '46',
#  '47',
#  '48',
#  '49th',
#  '4th',
#  '50',
#  '51',
#  '51st',
#  '52',
#  '54',
#  '5555',
#  '56th',
#  '57',
#  '571',
#  '5ecret',
#  '5tar',
#  '5th',
#  '5tory',
#  '5ystem',
#  '60',
#  '61',
#  '66',
#  '666',
#  '68',
#  '6th',
#  '700',
#  '72',
#  '73',
#  '75',
#  '77',
#  '786',
#  '79',
#  '7th',
#  '80',
#  '88',
#  '8mm',
#  '8th',
#  '911',
#  '92nd',
#  '93',
#  '96',
#  '97',
#  '99',
#  'aa',
#  'aah',
#  'aaj',
#  'aandhi',
#  'aang',
#  'aapke',
#  'aashiq',
#  'aashiqui',
#  'aatish',
#  'aaya',
#  'ab',
#  'abandoned',
#  'abar',
#  'abare',
#  'abbott',
#  'abducted',
#  'abduction',
#  'abe',
#  'able',
#  'about',
#  'above',
#  'absolom',
#  'absolute',
#  'abyme',
#  'abyss',
#  'academy',
#  'acapulco',
#  'accattone',
#  'accident',
#  'accidents',
#  'according',
#  'accursed',
#  'ace',
#  'aces',
#  'achtbeinige',
#  'acid',
#  'across',
#  'act',
#  'action',
#  'activity',
#  'actor',
#  'actors',
#  'acts',
#  'actually',
#  'adam',
#  'adams',
#  'adaption',
#  'addams',
#  'adele',
#  'admiral',
#  'adobenchâ',
#  'adrift',
#  'adult',
#  'advent',
#  'adventure',
#  'adventureland',
#  'adventurer',
#  'adventurers',
#  'adventures',
#  'adèle',
#  'ae',
#  'afei',
#  'affair',
#  'affairs',
#  'afi',
#  'afraid',
#  'africa',
#  'african',
#  'afstiros',
#  'after',
#  'afterlife',
#  'afternoon',
#  'ag',
#  'again',
#  'against',
#  'agantuk',
#  'agartha',
#  'age',
#  'agenda',
#  'agent',
#  'agents',
#  'ages',
#  'aggressor',
#  'agha',
#  'agito',
#  'agony',
#  'agora',
#  'aground',
#  'ahead',
#  'ahoy',
#  'ai',
#  'aileen',
#  'aimee',
#  'ain',
#  'air',
#  'airheads',
#  'airport',
#  'aisi',
#  'ajnabee',
#  'aka',
#  'akbar',
#  'akin',
#  'akira',
#  'akte',
#  'al',
#  'alabama',
#  'aladdin',
#  'alai',
#  'alamein',
#  'alamo',
#  'alan',
#  'alarm',
#  'alaska',
#  'alatriste',
#  'albert',
#  'alcatraz',
#  'alchemist',
#  'aldo',
#  'aldrich',
#  'alert',
#  'alexander',
#  'alexandra',
#  'alexandria',
#  'alexis',
#  'alfano',
#  'alfie',
#  'alfred',
#  'alfredo',
#  'algiers',
#  'ali',
#  'alibi',
#  'alice',
#  'alien',
#  'aliens',
#  'alien³',
#  'aliki',
#  'alive',
#  'all',
#  'allegro',
#  'allen',
#  'alles',
#  'alley',
#  'alligator',
#  'allin',
#  'allotment',
#  'allowed',
#  'allows',
#  'almighty',
#  'almost',
#  'alone',
#  'along',
#  'alonzo',
#  'alpha',
#  'alquist',
#  'already',
#  'als',
#  'also',
#  'altered',
#  'altitude',
#  'alvida',
#  'always',
#  'alwin',
#  'alyce',
#  'am',
#  'amadeus',
#  'amalia',
#  'amar',
#  'amarcord',
#  'amateur',
#  'amateurs',
#  'amazing',
#  'amazon',
#  'amazons',
#  'ambassador',
#  'amberson',
#  'ambition',
#  'ambush',
#  'ame',
#  'amelie',
#  'america',
#  'american',
#  'americanizing',
#  'americans',
#  'ames',
#  'amfar',
#  'amistad',
#  'amityville',
#  'ammayi',
#  'amok',
#  'among',
#  'amongst',
#  'amores',
#  'amour',
#  'amp',
#  'amputee',
#  'amrani',
#  'amsterdam',
#  'amuck',
#  'amusement',
#  'amy',
#  'an',
#  'ana',
#  'anaconda',
#  'anamorphic',
#  'anand',
#  'anari',
#  'anastasia',
#  'anatevka',
#  'anatol',
#  'anatolia',
#  'anatomy',
#  'anchorman',
#  'ancient',
#  'and',
#  'andalusian',
#  'andaz',
#  'anderland',
#  'anderson',
#  'andolan',
#  'andrej',
#  'android',
#  'andromeda',
#  'andrzej',
#  'andré',
#  'andy',
#  'anego',
#  'ange',
#  'angel',
#  'angeles',
#  'angelic',
#  'angelina',
#  'angels',
#  'anger',
#  'angles',
#  'angry',
#  'animal',
#  'animals',
#  'animated',
#  'animation',
#  'animator',
#  'animatrix',
#  'anime',
#  'ankles',
#  'anna',
#  'annabell',
#  'annapolis',
#  'anne',
#  'annemarie',
#  'annie',
#  'annihilation',
#  'anniversary',
#  'announce',
#  'annual',
#  'anonyma',
#  'another',
#  'ansari',
#  'anseon',
#  'answer',
#  'antarctic',
#  'antarctica',
#  'anthology',
#  'anthony',
#  'antichrist',
#  'antics',
#  'antiviral',
#  'antoine',
#  'antoinette',
#  'antwone',
#  'anus',
#  'anvil',
#  'any',
#  'anybody',
#  'anymore',
#  'anyone',
#  'anything',
#  'anywhere',
#  'apache',
#  'apaharan',
#  'apartment',
#  'ape',
#  'apes',
#  'aphrodite',
#  'apna',
#  'apne',
#  'apocalypse',
#  'apocalypto',
#  'apollo',
#  'appaloosa',
#  'apple',
#  'apples',
#  'appreciation',
#  'apprentice',
#  'appurushîdo',
#  'april',
#  'apus',
#  'aqua',
#  'aquamarine',
#  'aquarius',
#  'aquatic',
#  'arabeske',
#  'arabia',
#  'arabian',
#  'arabs',
#  'arac',
#  'arachnophobia',
#  'aradhana',
#  'aran',
#  'aranye',
#  'araujo',
#  'arbitration',
#  'arc',
#  'arcade',
#  'archibaldo',
#  'archie',
#  'architect',
#  'archives',
#  'arctic',
#  'ardennes',
#  'are',
#  'area',
#  'arena',
#  'argento',
#  'argo',
#  'argonauts',
#  'ari',
#  'ariane',
#  'ariel',
#  'arirang',
#  'arise',
#  'arises',
#  'aristocats',
#  'aristocrats',
#  'arizona',
#  'arjun',
#  'ark',
#  'arlington',
#  'arm',
#  'armageddon',
#  'armored',
#  'armour',
#  'arms',
#  'army',
#  'arn',
#  'arnhem',
#  'arnold',
#  'around',
#  'arrest',
#  'arrietty',
#  'arrival',
#  'arrow',
#  'arrows',
#  'arsenal',
#  'arsenic',
#  'art',
#  'artagnan',
#  'arthur',
#  'articles',
#  'artificial',
#  'artist',
#  'artists',
#  'arts',
#  'arya',
#  'as',
#  'ascension',
#  'ascent',
#  'ash',
#  'ashens',
#  'ashes',
#  'ask',
#  'asked',
#  'asoka',
#  'asphalt',
#  'ass',
#  'assassin',
#  'assassination',
#  'assassins',
#  'assault',
#  'assembly',
#  'assume',
#  'astaire',
#  'asterix',
#  'astray',
#  'astro',
#  'astronaut',
#  'asylum',
#  'at',
#  'atalanta',
#  'atanarjuat',
#  'ate',
#  'atlantic',
#  'atlantis',
#  'atlas',
#  'atomic',
#  'atonement',
#  'ator',
#  'atrocious',
#  'attack',
#  'attacks',
#  'attempt',
#  'attention',
#  'attic',
#  'attila',
#  'attractions',
#  'auberge',
#  'audio',
#  'audition',
#  'auf',
#  'august',
#  'aunt',
#  'aur',
#  'ausklang',
#  'austen',
#  'austens',
#  'austin',
#  'australia',
#  'australian',
#  'autarkist',
#  'auto',
#  'autopsy',
#  'autumn',
#  'avalanche',
#  'avalon',
#  'avatar',
#  'avatars',
#  'ave',
#  'avenger',
#  'avengers',
#  'aviator',
#  'avoid',
#  'awake',
#  'awakening',
#  'awara',
#  'awards',
#  'away',
#  'awesome',
#  'awful',
#  'awkward',
#  'ax',
#  'axe',
#  'azam',
#  'azigars',
#  'aziz',
#  'azkaban',
#  'azure',
#  'ba',
#  'baabul',
#  'baadasssss',
#  'baader',
#  'baaraat',
#  'baarìa',
#  'baat',
#  'baazi',
#  'babbler',
#  'babe',
#  'babel',
#  'babes',
#  'babette',
#  'babettes',
#  'babu',
#  'baby',
#  'babylon',
#  'babymakers',
#  'babysitters',
#  'babyy',
#  'bachelor',
#  'bachna',
#  'back',
#  'backbone',
#  'background',
#  'backwards',
#  'bad',
#  'badge',
#  'badger',
#  'badlands',
#  'badly',
#  'badmaa',
#  'bafana',
#  'baghban',
#  'baghdad',
#  'baghead',
#  'bags',
#  'bah',
#  'bahl',
#  'bail',
#  'bait',
#  'bak',
#  'baked',
#  'baker',
#  'baking',
#  'bakjwi',
#  'bala',
#  'balance',
#  'balboa',
#  'balfour',
#  'bali',
#  'ball',
#  'ballad',
#  'ballet',
#  'ballfieber',
#  'balloon',
#  'balloonatic',
#  'ballou',
#  'ballroom',
#  'balls',
#  'balthazar',
#  'balto',
#  'balzac',
#  'bamba',
#  'bambi',
#  'ban',
#  'bananas',
#  'band',
#  'bandidas',
#  'bandini',
#  'bandit',
#  'bandits',
#  'bane',
#  'bang',
#  'bangkok',
#  'bangrajan',
#  'bank',
#  'banks',
#  'banksy',
#  'bann',
#  'banquet',
#  'banzai',
#  'bar',
#  'barabar',
#  'baraka',
#  'baramui',
#  'baran',
#  'barbarella',
#  'barbarian',
#  'barbarians',
#  'barber',
#  'barbie',
#  'barcelona',
#  'bare',
#  'barefoot',
#  'barfi',
#  'bargain',
#  'barked',
#  'barley',
#  'baron',
#  'barrett',
#  'barry',
#  'bars',
#  'barsaat',
#  'bartholomew',
#  'bartlett',
#  'barton',
#  'basanti',
#  'bashir',
#  'bashu',
#  'basic',
#  'basket',
#  'basketball',
#  'basque',
#  'basquiat',
#  'bastards',
#  'basterds',
#  'bat21',
#  'bataan',
#  'bath',
#  'bathsheba',
#  'batman',
#  'battalion',
#  'battle',
#  'battleship',
#  'bay',
#  'be',
#  'beach',
#  'beam',
#  'bean',
#  'beanstalk',
#  'bear',
#  'bears',
#  'beast',
#  'beastly',
#  'beastmaster',
#  'beasts',
#  'beat',
#  'beating',
#  'beatrix',
#  'beats',
#  'beaufort',
#  'beauties',
#  'beautiful',
#  'beauty',
#  'beavis',
#  'bebop',
#  'because',
#  'becket',
#  'beckham',
#  'becomes',
#  'becoming',
#  'bed',
#  'bedevilled',
#  'bedoone',
#  'beds',
#  'bedtime',
#  'bee',
#  'beed',
#  'been',
#  'beer',
#  'beethoven',
#  'beetle',
#  'beetlejuice',
#  'before',
#  'beggar',
#  'beginner',
#  'beginners',
#  'beginning',
#  'begins',
#  'begotten',
#  'behalf',
#  'behind',
#  'behti',
#  'beijing',
#  'beilight',
#  'being',
#  'beings',
#  'beirut',
#  'bekushiru',
#  'beliefs',
#  'believe',
#  'believing',
#  'bell',
#  'belle',
#  'belleville',
#  'bellied',
#  'bells',
#  'belongs',
#  'beloved',
#  'below',
#  'belt',
#  'ben',
#  'bench',
#  'bende',
#  'bender',
#  'beneath',
#  'beneficiary',
#  'benefits',
#  'benjamin',
#  'benji',
#  'benny',
#  'bent',
#  'beowulf',
#  'bergerac',
#  'bergman',
#  'berlin',
#  'berling',
#  'bermuda',
#  'bernard',
#  'bernhard',
#  'bernie',
#  'bertie',
#  'beside',
#  'best',
#  'betrayal',
#  'betsy',
#  'bette',
#  'better',
#  'betty',
#  'between',
#  'beverly',
#  'beware',
#  'bewitched',
#  'beyond',
#  'bfg',
#  'bhagat',
#  'bhai',
#  'bheja',
#  'bhi',
#  'bi',
#  'bian',
#  'bianca',
#  'bible',
#  'bicycle',
#  'bier',
#  'big',
#  'bigalow',
#  'bigfoot',
#  'bigger',
#  'biggest',
#  'bijlee',
#  'bikini',
#  'bilko',
#  'bill',
#  'billing',
#  'billionaire',
#  'billu',
#  'billy',
#  'bin',
#  'bio',
#  'biography',
#  'biology',
#  'bird',
#  'birdcage',
#  'birdemic',
#  'birdie',
#  'birds',
#  'birdy',
#  'birth',
#  'birthday',
#  'bismarck',
#  'bit',
#  'bitangas',
#  'bitch',
#  'bitching',
#  'bitchy',
#  'bite',
#  'bites',
#  'bitter',
#  'bittersweet',
#  'biutiful',
#  'biwi',
#  'biyeolhan',
#  'black',
#  'blackfish',
#  'blackmail',
#  'blackout',
#  'blacksmith',
#  'blade',
#  'blaine',
#  'blair',
#  'blaise',
#  'blame',
#  'blank',
#  'blast',
#  'blatant',
#  'blaze',
#  'blazing',
#  'blemish',
#  'blend',
#  'blender',
#  'bless',
#  'blimp',
#  'blind',
#  'blinde',
#  'bling',
#  'blinkytm',
#  'blithe',
#  'blitz',
#  'blob',
#  'block',
#  'blockbusters',
#  'blocks',
#  'blond',
#  'blonde',
#  'blondes',
#  'blondie',
#  'blood',
#  'blooded',
#  'bloodhounds',
#  'bloodiest',
#  'bloodlust',
#  'bloods',
#  'bloodsport',
#  'bloody',
#  'bloom',
#  'blooming',
#  'blow',
#  'blowing',
#  'blows',
#  'blue',
#  'bluebeard',
#  'blueberry',
#  'blueprint',
#  'blues',
#  'bluff',
#  'blutmond',
#  'blutrache',
#  'blvd',
#  'bo',
#  'board',
#  'boat',
#  'boatman',
#  'bob',
#  'bobbed',
#  'bobby',
#  'bock',
#  'bodies',
#  'body',
#  'bodycheck',
#  'bodyguard',
#  'bodyguards',
#  'bodysong',
#  'bodyswitch',
#  'boetticher',
#  'boffo',
#  'bogart',
#  'bohemia',
#  'bohoguyeog',
#  'boiled',
#  'bokura',
#  'bold',
#  'boldly',
#  'bollywood',
#  'bolshevik',
#  'bolt',
#  'bomb',
#  'bombay',
#  'bomber',
#  'bombs',
#  'bommarillu',
#  'bonaparte',
#  'bond',
#  'bondage',
#  'bondi',
#  'bonds',
#  'bone',
#  'boner',
#  'bones',
#  'bong',
#  'bonner',
#  'bonnie',
#  'booby',
#  'boogeyman',
#  'boogie',
#  'book',
#  'booked',
#  'bookie',
#  'bookmark',
#  'books',
#  'booky',
#  'boom',
#  'boomerang',
#  'boonmee',
#  'boots',
#  'borat',
#  'border',
#  'borderland',
#  'borders',
#  'bored',
#  'borger',
#  'boris',
#  'born',
#  'borodino',
#  'bose',
#  'boshafte',
#  'boss',
#  'bossa',
#  'bottrop',
#  'boudu',
#  'boulevard',
#  'bounce',
#  'bound',
#  'boundaries',
#  'bounds',
#  'bounty',
#  'bourgeoisie',
#  'bourne',
#  'bout',
#  'bow',
#  ...]

# %%
lem = stem.WordNetLemmatizer()
stemmer = stem.snowball.EnglishStemmer()

# %%
testStr = 'A Beautiful Minds - genius and madness 2019th'
" ".join([stemmer.stem(x) for x in tokenize(testStr) if bool(re.match('^[0-9a-zA-Z]+$', x))])
# Out:
# 'a beauti mind genius and mad 2019th'

# %%
porter.stem("articles")
# Out:
# 'articl'

# %%
tfidfVector.get_feature_names()

# %%
preprocess = tfidfVector.build_preprocessor()

# %%
preprocess('Savage Harvest 2: October Blood')

# %%
display(tfidfVector.vocabulary_)

# %%
display(tfidfVector.idf_)

# %%
display(vectorizer.transform([text[0]]).toarray())
